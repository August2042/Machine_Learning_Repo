# %%
#importing the libraries
import pandas as pd
import numpy as np
import seaborn as sns                       #visualisation
import matplotlib.pyplot as plt             #visualisation
# %matplotlib inline     
sns.set(color_codes=True)

# %%
df = pd.read_csv('sentimentdataset.csv')   #importing the dataset
df.head(5)                                 #displaying first five rows
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# ...

# %%
df.tail(5)                          #displaying last five rows
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 727           728         732
# 728           729         733
# 729           730         734
# 730           731         735
# 731           732         736
#
#                                                   Text Sentiment  \
# 727  Collaborating on a science project that receiv...    Happy
# 728  Attending a surprise birthday party organized ...    Happy
# 729  Successfully fundraising for a school charity ...    Happy
# 730  Participating in a multicultural festival, cel...    Happy
# 731  Organizing a virtual talent show during challe...    Happy
#
#                Timestamp                                   User     Platform  \
# 727  2017-08-18 18:20:00       ScienceProjectSuccessHighSchool     Facebook
# 728  2018-06-22 14:15:00            BirthdayPartyJoyHighSchool    Instagram
# 729  2019-04-05 17:30:00   CharityFundraisingTriumphHighSchool      Twitter
# 730  2020-02-29 20:45:00    MulticulturalFestivalJoyHighSchool     Facebook
# ...

# %%
df.dtypes                       #checking the data type
# Out:
# Unnamed: 0.1      int64
# Unnamed: 0        int64
# Text             object
# Sentiment        object
# Timestamp        object
# User             object
# Platform         object
# Hashtags         object
# Retweets        float64
# Likes           float64
# Country          object
# Year              int64
# Month             int64
# Day               int64
# Hour              int64
# dtype: object

# %%
df = df.drop(['Unnamed: 0.1', 'Unnamed: 0'], axis=1)            #dropping the unnecessary columns
df.head(5)
# Out:
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# 0   #Nature #Park                                  15.0   30.0     USA
# 1   #Traffic #Morning                               5.0   10.0     Canada
# ...

# %%
# Rename the columns
df = df.rename(columns={
    'Text': 'Post_Content',
    'Sentiment': 'Sentiment_Label',
    'Timestamp': 'Post_Time',
    'User': 'Username',
    'Platform': 'Social_Media_Platform',
    'Hashtags': 'Post_Hashtags',
    'Retweets': 'Num_Retweets',
    'Likes': 'Num_Likes',
    'Country': 'User_Country',
    'Year': 'Post_Year',
    'Month': 'Post_Month',
    'Day': 'Post_Day',
    'Hour': 'Post_Hour'
})

# Display the first 5 rows with the renamed columns
df.head(5)
# Out:
#                                         Post_Content Sentiment_Label  \
# 0   Enjoying a beautiful day at the park!        ...      Positive
# 1   Traffic was terrible this morning.           ...      Negative
# 2   Just finished an amazing workout! 💪          ...      Positive
# 3   Excited about the upcoming weekend getaway!  ...      Positive
# 4   Trying out a new recipe for dinner tonight.  ...      Neutral
#
#              Post_Time        Username Social_Media_Platform  \
# 0  2023-01-15 12:30:00   User123                   Twitter
# 1  2023-01-15 08:45:00   CommuterX                 Twitter
# 2  2023-01-15 15:45:00   FitnessFan               Instagram
# 3  2023-01-15 18:20:00   AdventureX                Facebook
# 4  2023-01-15 19:55:00   ChefCook                 Instagram
#
#                                 Post_Hashtags  Num_Retweets  Num_Likes  \
# 0   #Nature #Park                                      15.0       30.0
# ...

# %%
df.shape                   #used to know the number of rows and columns
# Out:
# (732, 13)

# %%
duplicate_rows_df = df[df.duplicated()]                 #used to know the duplicate rows
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (20, 13)

# %%
df.count()      # Used to count the number of rows
# Out:
# Post_Content             732
# Sentiment_Label          732
# Post_Time                732
# Username                 732
# Social_Media_Platform    732
# Post_Hashtags            732
# Num_Retweets             732
# Num_Likes                732
# User_Country             732
# Post_Year                732
# Post_Month               732
# Post_Day                 732
# Post_Hour                732
# dtype: int64

# %%
df = df.drop_duplicates()              #used to remove the duplicate rows
df.head(5)
# Out:
#                                         Post_Content Sentiment_Label  \
# 0   Enjoying a beautiful day at the park!        ...      Positive
# 1   Traffic was terrible this morning.           ...      Negative
# 2   Just finished an amazing workout! 💪          ...      Positive
# 3   Excited about the upcoming weekend getaway!  ...      Positive
# 4   Trying out a new recipe for dinner tonight.  ...      Neutral
#
#              Post_Time        Username Social_Media_Platform  \
# 0  2023-01-15 12:30:00   User123                   Twitter
# 1  2023-01-15 08:45:00   CommuterX                 Twitter
# 2  2023-01-15 15:45:00   FitnessFan               Instagram
# 3  2023-01-15 18:20:00   AdventureX                Facebook
# 4  2023-01-15 19:55:00   ChefCook                 Instagram
#
#                                 Post_Hashtags  Num_Retweets  Num_Likes  \
# 0   #Nature #Park                                      15.0       30.0
# ...

# %%
df.count()                      # Used to count the number of rows
# Out:
# Post_Content             712
# Sentiment_Label          712
# Post_Time                712
# Username                 712
# Social_Media_Platform    712
# Post_Hashtags            712
# Num_Retweets             712
# Num_Likes                712
# User_Country             712
# Post_Year                712
# Post_Month               712
# Post_Day                 712
# Post_Hour                712
# dtype: int64

# %%
print(df.isnull().sum()) #Check the missing values in the dataset
# Out:
# Post_Content             0
# Sentiment_Label          0
# Post_Time                0
# Username                 0
# Social_Media_Platform    0
# Post_Hashtags            0
# Num_Retweets             0
# Num_Likes                0
# User_Country             0
# Post_Year                0
# Post_Month               0
# Post_Day                 0
# Post_Hour                0
# dtype: int64

# %%
#Boxplot
sns.boxplot(x=df['Num_Retweets'])
# Out:
# <AxesSubplot: xlabel='Num_Retweets'>

# %%
#Boxplot
sns.boxplot(x=df['Num_Likes'])
# Out:
# <AxesSubplot: xlabel='Num_Likes'>

# %%
# Bar chart for 'User' column
df['Username'].value_counts().nlargest(40).plot(kind='bar', figsize=(10, 5), color='skyblue')
plt.title("User Distribution in Sentiment Dataset")
plt.ylabel('Number of Occurrences')
plt.xlabel('Users')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %%
# Bar chart for user country distribution
df['User_Country'].value_counts().nlargest(15).plot(kind='bar', figsize=(10, 5), color='skyblue')
plt.title("User Country Distribution")
plt.ylabel('Number of Users')
plt.xlabel('Countries')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Bar chart for platform-wise counts
df['Social_Media_Platform'].value_counts().plot(kind='bar', figsize=(10, 5), color='skyblue')
plt.title("Distribution Across Social Media Platforms")
plt.ylabel('Number of Posts')
plt.xlabel('Social Media Platforms')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Bar chart for post distribution by hour
df['Post_Hour'].value_counts().sort_index().plot(kind='bar', figsize=(10, 5), color='skyblue')
plt.title("Hourly Distribution of Posts")
plt.ylabel('Number of Posts')
plt.xlabel('Hour of the Day')
plt.show()

# %%
# Scatter plot for Num_Retweets and Num_Likes
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Num_Retweets', y='Num_Likes', data=df, color='skyblue')
plt.title('Scatter Plot: Num_Retweets vs. Num_Likes')
plt.xlabel('Number of Retweets')
plt.ylabel('Number of Likes')
plt.show()
